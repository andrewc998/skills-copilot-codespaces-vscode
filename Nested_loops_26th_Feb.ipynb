# %% [markdown]
# <a href="https://colab.research.google.com/github/andrewc998/skills-copilot-codespaces-vscode/blob/main/Nested_loops_26th_Feb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Student Details - Sheet1.csv')
print(df)
df.head()
# Out:
#                name                      email   age                course
# 0          John Doe          john.doe@gmail.com    20     Computer Science
# 1        Jane Smith        jane.smith@gmail.com    22         Data Science
# 2     Alice Johnson     alice.johnson@gmail.com    24       Cyber Security
# 3       Kamau Kamau       kamau.kamau@gmail.com    26     Acturial Science
# 4  Francis Ndirangu  francis.ndirangu@gmail.com    28  Mechanical Engineer
# 5     Michael Olise     michael.olise@gmail.com    22           Footballer
# 6        Harry Kane         harry.kane@students    33           Top Scorer
#                name                      email   age                course
# 0          John Doe          john.doe@gmail.com    20     Computer Science
# 1        Jane Smith        jane.smith@gmail.com    22         Data Science
# 2     Alice Johnson     alice.johnson@gmail.com    24       Cyber Security
# ...

# %%
def get_students_details(path):
  df = pd.read_csv(path)
  return df

# %%
data = get_students_details('/content/Student Details - Sheet1.csv')
print(data)
# Out:
#                name                      email   age                course
# 0          John Doe          john.doe@gmail.com    20     Computer Science
# 1        Jane Smith        jane.smith@gmail.com    22         Data Science
# 2     Alice Johnson     alice.johnson@gmail.com    24       Cyber Security
# 3       Kamau Kamau       kamau.kamau@gmail.com    26     Acturial Science
# 4  Francis Ndirangu  francis.ndirangu@gmail.com    28  Mechanical Engineer
# 5     Michael Olise     michael.olise@gmail.com    22           Footballer
# 6        Harry Kane         harry.kane@students    33           Top Scorer

# %%
#emails = [item["email"] for item in data]
#emails = [item["email"] for item in data]
data = get_students_details('/content/Student Details - Sheet1.csv')
# Check if 'email' column exists in the DataFrame
if 'name' in data.columns:
  name = data['name'].tolist()
  print("\n".join(name))
# Out:
# John Doe
# Jane Smith
# Alice Johnson
# Kamau Kamau
# Francis Ndirangu
# Michael Olise
# Harry Kane

# %%
# Convert the DataFrame to a list of dictionaries
data_list = data.to_dict('records')
emails = [item["email"] for item in data_list]
print(emails)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-d9b6d1c6d3a8> in <cell line: 0>()
#       1 # Convert the DataFrame to a list of dictionaries
#       2 data_list = data.to_dict('records')
# ----> 3 emails = [item["email"] for item in data_list]
#       4 print(emails)
#
# <ipython-input-8-d9b6d1c6d3a8> in <listcomp>(.0)
#       1 # Convert the DataFrame to a list of dictionaries
#       2 data_list = data.to_dict('records')
# ----> 3 emails = [item["email"] for item in data_list]
#       4 print(emails)
#
# KeyError: 'email'
